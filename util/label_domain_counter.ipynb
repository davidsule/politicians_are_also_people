# %% [markdown]
# ### Check label counts per domain
# For deciding on unique entities

# %%
import json
from collections import Counter

# %%
types = ["train", "dev", "test"]
domains=['ai', 'literature', 'music', 'news', 'politics', 'science']
counts_per_domain = {}
data_path = "../data/crossre_data/"
for d in domains:
    counts_per_domain[d] = {}
    for t in types:
        counts_per_domain[d][t] = Counter()
        with open(f"{data_path}{d}-{t}.json") as f:
            for json_elem in f:
                document = json.loads(json_elem)
                for ner in document["ner"]:
                    counts_per_domain[d][t].update([ner[2]])

print(json.dumps(counts_per_domain, indent=4))
# Out:
# {
#     "ai": {
#         "train": {
#             "product": 57,
#             "field": 39,
#             "task": 59,
#             "researcher": 54,
#             "university": 27,
#             "programlang": 25,
#             "algorithm": 80,
#             "misc": 45,
#             "metrics": 27,
#             "organisation": 50,
#             "conference": 24,
#             "country": 29,
#             "location": 10,
#             "person": 6
#         },
#         "dev": {
#             "metrics": 146,
#             "algorithm": 178,
#             "misc": 186,
#             "person": 41,
#             "product": 174,
#             "organisation": 95,
#             "task": 146,
#             "university": 59,
#             "conference": 83,
#             "researcher": 142,
#             "field": 177,
#             "programlang": 34,
#             "country": 43,
#             "location": 42,
#             "academicjournal": 2
#         },
#         "test": {
#             "algorithm": 179,
#             "organisation": 148,
#             "conference": 86,
#             "misc": 186,
#             "product": 198,
#             "task": 219,
#             "field": 205,
#             "metrics": 191,
#             "researcher": 158,
#             "programlang": 60,
#             "country": 44,
#             "location": 39,
#             "person": 68,
#             "university": 28,
#             "academicjournal": 1,
#             "event": 1
#         }
#     },
#     "literature": {
#         "train": {
#             "person": 46,
#             "country": 25,
#             "writer": 135,
#             "misc": 54,
#             "book": 93,
#             "award": 34,
#             "literarygenre": 36,
#             "poem": 46,
#             "location": 26,
#             "magazine": 16,
#             "event": 10,
#             "organisation": 18,
#             "song": 1
#         },
#         "dev": {
#             "literarygenre": 153,
#             "book": 327,
#             "award": 124,
#             "location": 111,
#             "poem": 74,
#             "misc": 218,
#             "writer": 543,
#             "organisation": 114,
#             "person": 200,
#             "event": 65,
#             "country": 123,
#             "magazine": 69,
#             "scientist": 1,
#             "song": 2,
#             "musicgenre": 1,
#             "band": 2,
#             "album": 1,
#             "programlang": 4
#         },
#         "test": {
#             "writer": 567,
#             "book": 406,
#             "literarygenre": 202,
#             "misc": 244,
#             "person": 177,
#             "album": 2,
#             "organisation": 111,
#             "poem": 126,
#             "location": 98,
#             "award": 140,
#             "event": 46,
#             "country": 97,
#             "magazine": 60,
#             "band": 1,
#             "university": 1
#         }
#     },
#     "music": {
#         "train": {
#             "location": 30,
#             "event": 12,
#             "country": 27,
#             "band": 126,
#             "person": 17,
#             "song": 27,
#             "musicalartist": 105,
#             "musicgenre": 90,
#             "misc": 19,
#             "album": 89,
#             "organisation": 38,
#             "award": 69,
#             "musicalinstrument": 2,
#             "magazine": 1
#         },
#         "dev": {
#             "event": 75,
#             "musicalartist": 440,
#             "location": 172,
#             "organisation": 130,
#             "album": 259,
#             "song": 163,
#             "award": 215,
#             "band": 369,
#             "musicgenre": 343,
#             "person": 52,
#             "country": 112,
#             "misc": 104,
#             "musicalinstrument": 34
#         },
#         "test": {
#             "song": 205,
#             "band": 384,
#             "album": 296,
#             "musicgenre": 401,
#             "musicalartist": 462,
#             "organisation": 182,
#             "misc": 149,
#             "country": 141,
#             "award": 221,
#             "person": 73,
#             "location": 284,
#             "musicalinstrument": 20,
#             "event": 67
#         }
#     },
#     "news": {
#         "train": {
#             "organisation": 64,
#             "misc": 80,
#             "person": 62,
#             "location": 137,
#             "country": 7
#         },
#         "dev": {
#             "organisation": 208,
#             "location": 65,
#             "misc": 58,
#             "person": 200,
#             "country": 78
#         },
#         "test": {
#             "country": 197,
#             "person": 424,
#             "location": 65,
#             "misc": 63,
#             "organisation": 107
#         }
#     },
#     "politics": {
#         "train": {
#             "politicalparty": 108,
#             "politician": 327,
#             "election": 54,
#             "location": 34,
#             "musicalartist": 2,
#             "organisation": 31,
#             "musicalinstrument": 1,
#             "song": 1,
#             "album": 2,
#             "misc": 43,
#             "person": 4,
#             "country": 24,
#             "event": 8
#         },
#         "dev": {
#             "election": 442,
#             "politicalparty": 955,
#             "organisation": 295,
#             "misc": 93,
#             "politician": 234,
#             "person": 21,
#             "event": 11,
#             "location": 143,
#             "country": 72,
#             "book": 1
#         },
#         "test": {
#             "country": 273,
#             "politician": 243,
#             "election": 287,
#             "person": 100,
#             "organisation": 273,
#             "location": 489,
#             "misc": 147,
#             "politicalparty": 662,
#             "event": 15,
#             "university": 51
#         }
#     },
#     "science": {
#         "train": {
#             "chemicalcompound": 49,
#             "scientist": 63,
#             "university": 31,
#             "astronomicalobject": 66,
#             "misc": 84,
#             "protein": 20,
#             "person": 62,
#             "location": 25,
#             "theory": 4,
#             "enzyme": 15,
#             "organisation": 56,
#             "award": 28,
#             "country": 6,
#             "event": 12,
#             "book": 6,
#             "discipline": 4,
#             "chemicalelement": 10,
#             "academicjournal": 10
#         },
#         "dev": {
#             "organisation": 226,
#             "academicjournal": 126,
#             "scientist": 254,
#             "chemicalcompound": 166,
#             "misc": 265,
#             "university": 110,
#             "discipline": 38,
#             "location": 103,
#             "protein": 66,
#             "astronomicalobject": 293,
#             "chemicalelement": 15,
#             "event": 32,
#             "person": 117,
#             "award": 118,
#             "enzyme": 37,
#             "theory": 7,
#             "country": 21
#         },
#         "test": {
#             "organisation": 203,
#             "astronomicalobject": 271,
#             "misc": 398,
#             "chemicalcompound": 133,
#             "protein": 125,
#             "person": 194,
#             "university": 87,
#             "scientist": 303,
#             "enzyme": 60,
#             "award": 81,
#             "event": 27,
#             "location": 128,
#             "country": 19,
#             "academicjournal": 121,
#             "chemicalelement": 62,
#             "discipline": 48,
#             "book": 3,
#             "theory": 10
#         }
#     }
# }

# %%
counts_per_label = {}
for domain in domains:
    for data_type in types:
        for label, count in dict(counts_per_domain[domain][data_type]).items():
            if label in counts_per_label:
                if domain in counts_per_label[label]:
                    counts_per_label[label][domain][data_type] = count
                else:
                    counts_per_label[label][domain] = {data_type: count}
            else:
                counts_per_label[label] = {domain: {data_type: count}}

print(json.dumps(counts_per_label, indent=4))
# Out:
# {
#     "product": {
#         "ai": {
#             "train": 57,
#             "dev": 174,
#             "test": 198
#         }
#     },
#     "field": {
#         "ai": {
#             "train": 39,
#             "dev": 177,
#             "test": 205
#         }
#     },
#     "task": {
#         "ai": {
#             "train": 59,
#             "dev": 146,
#             "test": 219
#         }
#     },
#     "researcher": {
#         "ai": {
#             "train": 54,
#             "dev": 142,
#             "test": 158
#         }
#     },
#     "university": {
#         "ai": {
#             "train": 27,
#             "dev": 59,
#             "test": 28
#         },
#         "literature": {
#             "test": 1
#         },
#         "politics": {
#             "test": 51
#         },
#         "science": {
#             "train": 31,
#             "dev": 110,
#             "test": 87
#         }
#     },
#     "programlang": {
#         "ai": {
#             "train": 25,
#             "dev": 34,
#             "test": 60
#         },
#         "literature": {
#             "dev": 4
#         }
#     },
#     "algorithm": {
#         "ai": {
#             "train": 80,
#             "dev": 178,
#             "test": 179
#         }
#     },
#     "misc": {
#         "ai": {
#             "train": 45,
#             "dev": 186,
#             "test": 186
#         },
#         "literature": {
#             "train": 54,
#             "dev": 218,
#             "test": 244
#         },
#         "music": {
#             "train": 19,
#             "dev": 104,
#             "test": 149
#         },
#         "news": {
#             "train": 80,
#             "dev": 58,
#             "test": 63
#         },
#         "politics": {
#             "train": 43,
#             "dev": 93,
#             "test": 147
#         },
#         "science": {
#             "train": 84,
#             "dev": 265,
#             "test": 398
#         }
#     },
#     "metrics": {
#         "ai": {
#             "train": 27,
#             "dev": 146,
#             "test": 191
#         }
#     },
#     "organisation": {
#         "ai": {
#             "train": 50,
#             "dev": 95,
#             "test": 148
#         },
#         "literature": {
#             "train": 18,
#             "dev": 114,
#             "test": 111
#         },
#         "music": {
#             "train": 38,
#             "dev": 130,
#             "test": 182
#         },
#         "news": {
#             "train": 64,
#             "dev": 208,
#             "test": 107
#         },
#         "politics": {
#             "train": 31,
#             "dev": 295,
#             "test": 273
#         },
#         "science": {
#             "train": 56,
#             "dev": 226,
#             "test": 203
#         }
#     },
#     "conference": {
#         "ai": {
#             "train": 24,
#             "dev": 83,
#             "test": 86
#         }
#     },
#     "country": {
#         "ai": {
#             "train": 29,
#             "dev": 43,
#             "test": 44
#         },
#         "literature": {
#             "train": 25,
#             "dev": 123,
#             "test": 97
#         },
#         "music": {
#             "train": 27,
#             "dev": 112,
#             "test": 141
#         },
#         "news": {
#             "train": 7,
#             "dev": 78,
#             "test": 197
#         },
#         "politics": {
#             "train": 24,
#             "dev": 72,
#             "test": 273
#         },
#         "science": {
#             "train": 6,
#             "dev": 21,
#             "test": 19
#         }
#     },
#     "location": {
#         "ai": {
#             "train": 10,
#             "dev": 42,
#             "test": 39
#         },
#         "literature": {
#             "train": 26,
#             "dev": 111,
#             "test": 98
#         },
#         "music": {
#             "train": 30,
#             "dev": 172,
#             "test": 284
#         },
#         "news": {
#             "train": 137,
#             "dev": 65,
#             "test": 65
#         },
#         "politics": {
#             "train": 34,
#             "dev": 143,
#             "test": 489
#         },
#         "science": {
#             "train": 25,
#             "dev": 103,
#             "test": 128
#         }
#     },
#     "person": {
#         "ai": {
#             "train": 6,
#             "dev": 41,
#             "test": 68
#         },
#         "literature": {
#             "train": 46,
#             "dev": 200,
#             "test": 177
#         },
#         "music": {
#             "train": 17,
#             "dev": 52,
#             "test": 73
#         },
#         "news": {
#             "train": 62,
#             "dev": 200,
#             "test": 424
#         },
#         "politics": {
#             "train": 4,
#             "dev": 21,
#             "test": 100
#         },
#         "science": {
#             "train": 62,
#             "dev": 117,
#             "test": 194
#         }
#     },
#     "academicjournal": {
#         "ai": {
#             "dev": 2,
#             "test": 1
#         },
#         "science": {
#             "train": 10,
#             "dev": 126,
#             "test": 121
#         }
#     },
#     "event": {
#         "ai": {
#             "test": 1
#         },
#         "literature": {
#             "train": 10,
#             "dev": 65,
#             "test": 46
#         },
#         "music": {
#             "train": 12,
#             "dev": 75,
#             "test": 67
#         },
#         "politics": {
#             "train": 8,
#             "dev": 11,
#             "test": 15
#         },
#         "science": {
#             "train": 12,
#             "dev": 32,
#             "test": 27
#         }
#     },
#     "writer": {
#         "literature": {
#             "train": 135,
#             "dev": 543,
#             "test": 567
#         }
#     },
#     "book": {
#         "literature": {
#             "train": 93,
#             "dev": 327,
#             "test": 406
#         },
#         "politics": {
#             "dev": 1
#         },
#         "science": {
#             "train": 6,
#             "test": 3
#         }
#     },
#     "award": {
#         "literature": {
#             "train": 34,
#             "dev": 124,
#             "test": 140
#         },
#         "music": {
#             "train": 69,
#             "dev": 215,
#             "test": 221
#         },
#         "science": {
#             "train": 28,
#             "dev": 118,
#             "test": 81
#         }
#     },
#     "literarygenre": {
#         "literature": {
#             "train": 36,
#             "dev": 153,
#             "test": 202
#         }
#     },
#     "poem": {
#         "literature": {
#             "train": 46,
#             "dev": 74,
#             "test": 126
#         }
#     },
#     "magazine": {
#         "literature": {
#             "train": 16,
#             "dev": 69,
#             "test": 60
#         },
#         "music": {
#             "train": 1
#         }
#     },
#     "song": {
#         "literature": {
#             "train": 1,
#             "dev": 2
#         },
#         "music": {
#             "train": 27,
#             "dev": 163,
#             "test": 205
#         },
#         "politics": {
#             "train": 1
#         }
#     },
#     "scientist": {
#         "literature": {
#             "dev": 1
#         },
#         "science": {
#             "train": 63,
#             "dev": 254,
#             "test": 303
#         }
#     },
#     "musicgenre": {
#         "literature": {
#             "dev": 1
#         },
#         "music": {
#             "train": 90,
#             "dev": 343,
#             "test": 401
#         }
#     },
#     "band": {
#         "literature": {
#             "dev": 2,
#             "test": 1
#         },
#         "music": {
#             "train": 126,
#             "dev": 369,
#             "test": 384
#         }
#     },
#     "album": {
#         "literature": {
#             "dev": 1,
#             "test": 2
#         },
#         "music": {
#             "train": 89,
#             "dev": 259,
#             "test": 296
#         },
#         "politics": {
#             "train": 2
#         }
#     },
#     "musicalartist": {
#         "music": {
#             "train": 105,
#             "dev": 440,
#             "test": 462
#         },
#         "politics": {
#             "train": 2
#         }
#     },
#     "musicalinstrument": {
#         "music": {
#             "train": 2,
#             "dev": 34,
#             "test": 20
#         },
#         "politics": {
#             "train": 1
#         }
#     },
#     "politicalparty": {
#         "politics": {
#             "train": 108,
#             "dev": 955,
#             "test": 662
#         }
#     },
#     "politician": {
#         "politics": {
#             "train": 327,
#             "dev": 234,
#             "test": 243
#         }
#     },
#     "election": {
#         "politics": {
#             "train": 54,
#             "dev": 442,
#             "test": 287
#         }
#     },
#     "chemicalcompound": {
#         "science": {
#             "train": 49,
#             "dev": 166,
#             "test": 133
#         }
#     },
#     "astronomicalobject": {
#         "science": {
#             "train": 66,
#             "dev": 293,
#             "test": 271
#         }
#     },
#     "protein": {
#         "science": {
#             "train": 20,
#             "dev": 66,
#             "test": 125
#         }
#     },
#     "theory": {
#         "science": {
#             "train": 4,
#             "dev": 7,
#             "test": 10
#         }
#     },
#     "enzyme": {
#         "science": {
#             "train": 15,
#             "dev": 37,
#             "test": 60
#         }
#     },
#     "discipline": {
#         "science": {
#             "train": 4,
#             "dev": 38,
#             "test": 48
#         }
#     },
#     "chemicalelement": {
#         "science": {
#             "train": 10,
#             "dev": 15,
#             "test": 62
#         }
#     }
# }
